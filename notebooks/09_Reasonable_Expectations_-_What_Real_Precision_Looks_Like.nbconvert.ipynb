# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/ReevesJustin/data-driven-reloading/blob/main/notebooks/09_Reasonable_Expectations_-_What_Real_Precision_Looks_Like.ipynb)
#
# [![Binder](https://mybinder.org/badge_logo.svg)](https://mybinder.org/v2/gh/ReevesJustin/data-driven-reloading/main?filepath=notebooks/09_Reasonable_Expectations_-_What_Real_Precision_Looks_Like.ipynb)

# %% [markdown]
# Time to complete: 10-15 minutes

# %% [markdown]
# # Reasonable Expectations - What Real Precision Looks Like
#
# ## Introduction
#
# Address **pain** of unrealistic expectations from small samples.
#
# ## Section 1: Three Contributors to Dispersion
#
# **Rifle + Ammunition:** The mechanical consistency.
# **Shooter:** Fundamentals.
# **Recoil:** The biggest disruptor.
#
# ## Section 2: Benchmarks
#
# **Realistic benchmarks** with large samples.
#
# ## Section 3: WEZ Thinking
#
# **Weapon Employment Zone** for hit probability.
#
# ## Audette Ladders
#
# **POI** largely recoil induced. Demo of effect at 400y.

# %%
# WEZ simulation
import numpy as np
import matplotlib.pyplot as plt

# Simple hit probability
moa = 1
target_size = 12  # inches
range_yards = 400

# Approximate
group_radius = (moa / 60) * range_yards * 36 / 12  # inches
if group_radius < target_size / 2:
    prob = 1
else:
    prob = (target_size / 2) / group_radius

print(f'Hit probability: {prob:.2f}')

# Plot
plt.scatter([0], [0], s=group_radius*10)
plt.xlim(-target_size, target_size)
plt.ylim(-target_size, target_size)
plt.show()
# Out:
# Hit probability: 0.30

# %% [markdown]
# > **Key Takeaways**
# > - Real-world precision limits exist for all shooting systems
# > - Component variation sets fundamental boundaries
# > - Statistical analysis defines achievable performance levels
# > - Understanding limits prevents unrealistic goals
# > - Accepting natural variation leads to better satisfaction

# %% [markdown]
# [Previous: 08_Your_Experiments_Template.ipynb](08_Your_Experiments_Template.ipynb) | [Next: 10_When_IS_a_Result_Real.ipynb](10_When_IS_a_Result_Real.ipynb)
