# %% [markdown]
# # Your Experiment Kit
#
# ## Take Charge of Your Tests
#
# This blank slate includes:
# Data input tables.
# Auto-charts (velocity lines, histograms, group overlays).
# Easy stats (intervals explained simply).
# How-to: Clone this notebook, drop in your chrono CSV, tweak labels, and uncover facts.
#
# ## Steps
#
# 1. Import your data.
# 2. Hit run on cells.
# 3. Decode the findings.

# %%
# Load data
import pandas as pd
import matplotlib.pyplot as plt

# Example data - swap with your CSV
data = {'Velocity': [2700, 2710, 2695]}
df = pd.DataFrame(data)

# Plot - wide
plt.figure(figsize=(10, 6))
plt.hist(df['Velocity'])
plt.show()

# Stats
print(f'Avg: {df["Velocity"].mean():.1f}, SD: {df["Velocity"].std():.1f}')
